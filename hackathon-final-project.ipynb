# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

# %%
train_data = pd.read_csv("trainair.csv")

# %%
train_data.head(5)
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
train_data.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
train_data.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
sns.heatmap(((train_data.corr())*100), annot=True)
# Out:
# <AxesSubplot:>

# %%
train_data.drop(columns=['id','Arrival Delay in Minutes','Unnamed: 0'],inplace=True)

# %%
train_data.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       3              1  ...             5
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
s = (train_data.dtypes =="object")
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

# %%
ord_encoder = OrdinalEncoder()
train_data[object_cols] = ord_encoder.fit_transform(train_data[object_cols])
train_data.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0     1.0            0.0   13             1.0    2.0              460
# 1     1.0            1.0   25             0.0    0.0              235
# 2     0.0            0.0   26             0.0    0.0             1142
# 3     0.0            0.0   25             0.0    0.0              562
# 4     1.0            0.0   61             0.0    0.0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       3              1  ...             5
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
cols = ['Flight Distance', 'Departure Delay in Minutes', 'Class']
train_data[cols] = sc.fit_transform(train_data[cols])

# %%
train_data
# Out:
#         Gender  Customer Type  Age  Type of Travel     Class  Flight Distance  \
# 0          1.0            0.0   13             1.0  2.264618        -0.731539
# 1          1.0            1.0   25             0.0 -0.957054        -0.957184
# 2          0.0            0.0   26             0.0 -0.957054        -0.047584
# 3          0.0            0.0   25             0.0 -0.957054        -0.629246
# 4          1.0            0.0   61             0.0 -0.957054        -0.978244
# ...        ...            ...  ...             ...       ...              ...
# 103899     0.0            1.0   23             0.0  0.653782        -1.000307
# 103900     1.0            0.0   49             0.0 -0.957054         1.160869
# 103901     1.0            1.0   30             0.0 -0.957054         0.807860
# 103902     0.0            1.0   22             0.0  0.653782        -0.189991
# 103903     1.0            0.0   27             0.0 -0.957054         0.535081
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X_train = train_data.drop('satisfaction', axis=1)
y_train = train_data['satisfaction']

# %%
X_train
# Out:
#         Gender  Customer Type  Age  Type of Travel     Class  Flight Distance  \
# 0          1.0            0.0   13             1.0  2.264618        -0.731539
# 1          1.0            1.0   25             0.0 -0.957054        -0.957184
# 2          0.0            0.0   26             0.0 -0.957054        -0.047584
# 3          0.0            0.0   25             0.0 -0.957054        -0.629246
# 4          1.0            0.0   61             0.0 -0.957054        -0.978244
# ...        ...            ...  ...             ...       ...              ...
# 103899     0.0            1.0   23             0.0  0.653782        -1.000307
# 103900     1.0            0.0   49             0.0 -0.957054         1.160869
# 103901     1.0            1.0   30             0.0 -0.957054         0.807860
# 103902     0.0            1.0   22             0.0  0.653782        -0.189991
# 103903     1.0            0.0   27             0.0 -0.957054         0.535081
#
# ...

# %%
model =  RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
test_data = pd.read_csv('testair.csv')

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
s = (test_data.dtypes =="object")
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

# %%
test_data
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
test_data[object_cols] = ord_encoder.transform(test_data[object_cols])

# %%
test_data
# Out:
#        Unnamed: 0     id  Gender  Customer Type  Age  Type of Travel  Class  \
# 0               0  19556     0.0            0.0   52             0.0    1.0
# 1               1  90035     0.0            0.0   36             0.0    0.0
# 2               2  12360     1.0            1.0   20             0.0    1.0
# 3               3  77959     1.0            0.0   44             0.0    0.0
# 4               4  36875     0.0            0.0   49             0.0    1.0
# ...           ...    ...     ...            ...  ...             ...    ...
# 25971       25971  78463     1.0            1.0   34             0.0    0.0
# 25972       25972  71167     1.0            0.0   23             0.0    0.0
# 25973       25973  37675     0.0            0.0   17             1.0    1.0
# 25974       25974  90086     1.0            0.0   14             0.0    0.0
# 25975       25975  34799     0.0            0.0   42             1.0    1.0
#
#        Flight Distance  Inflight wifi service  \
# ...

# %%
test_data
# Out:
#        Unnamed: 0     id  Gender  Customer Type  Age  Type of Travel  Class  \
# 0               0  19556     0.0            0.0   52             0.0    1.0
# 1               1  90035     0.0            0.0   36             0.0    0.0
# 2               2  12360     1.0            1.0   20             0.0    1.0
# 3               3  77959     1.0            0.0   44             0.0    0.0
# 4               4  36875     0.0            0.0   49             0.0    1.0
# ...           ...    ...     ...            ...  ...             ...    ...
# 25971       25971  78463     1.0            1.0   34             0.0    0.0
# 25972       25972  71167     1.0            0.0   23             0.0    0.0
# 25973       25973  37675     0.0            0.0   17             1.0    1.0
# 25974       25974  90086     1.0            0.0   14             0.0    0.0
# 25975       25975  34799     0.0            0.0   42             1.0    1.0
#
#        Flight Distance  Inflight wifi service  \
# ...

# %%
test_data.drop(columns=['id','Arrival Delay in Minutes','Unnamed: 0'],inplace=True)

# %%
test_data
# Out:
#        Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0         0.0            0.0   52             0.0    1.0              160
# 1         0.0            0.0   36             0.0    0.0             2863
# 2         1.0            1.0   20             0.0    1.0              192
# 3         1.0            0.0   44             0.0    0.0             3377
# 4         0.0            0.0   49             0.0    1.0             1182
# ...       ...            ...  ...             ...    ...              ...
# 25971     1.0            1.0   34             0.0    0.0              526
# 25972     1.0            0.0   23             0.0    0.0              646
# 25973     0.0            0.0   17             1.0    1.0              828
# 25974     1.0            0.0   14             0.0    0.0             1127
# 25975     0.0            0.0   42             1.0    1.0              264
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %%
cols = ['Flight Distance', 'Departure Delay in Minutes', 'Class']
test_data[cols] = sc.transform(test_data[cols])

# %%
y_test = X_test[['satisfaction']]

# %%
X_test.drop('satisfaction',axis=1,inplace=True)

# %%
X_test = test_data  # Assuming X_test is preprocessed
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
(accuracy_score(y_pred,y_test)*100)
# Out:
# 96.31582999692023
